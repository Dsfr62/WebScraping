# %%
import pandas as pd

# Colocar o caminho da planilha excel
path = '//content//USA_Rugby_CRU.xlsx'

planilha = pd.read_excel(path)

# O primeiro parâmetro é o nome do arquivo
planilha_csv = planilha.to_csv('USA_Rugby_CRU.csv', index = False)

planilha_csv
